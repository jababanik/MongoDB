# %%
from pymongo import MongoClient
from pprint import pprint

# %%
def get_connect():
    return MongoClient("mongodb+srv://jaba:lol.java@darksourceofcode.cs3ir.mongodb.net/<dbname>?retryWrites=true&w=majority")

# %%
client = get_connect()

# %%
db = client.loc_test #database name is loc_test

# %%
cursor = db.addresses.find({'YES / NO': 'No'}) #table name is addresses

# %%
from pprint import pprint
for address in cursor:
    pprint(address)
# Out:
# {'ADDRESS': 'AGV-6 vedic village, sikharpur, Rajarhat, south 24 pragnas, '
#             'kolkata, WB 7000135',
#  'Action -2': '',
#  'CATEGORY': 'RESORT',
#  'Email address': '',
#  'NAME OF RESORT': 'Aqua golf villa resort',
#  'OWNER Name': '',
#  'RESORT NUMBER': '9830564797',
#  'Whatsapp': '',
#  'YES / NO': 'No',
#  '_id': ObjectId('5f01eee936ce0711bce7e6f8'),
#  'call status': '',
#  'caller': '',
#  'no': '2',
#  'pax': '115'}
# {'ADDRESS': 'kochpukhur, p.o Hatgachia, India 700156',
#  'Action -2': '',
#  'CATEGORY': 'RESORT',
#  'Email address': '',
#  'NAME OF RESORT': 'Aquatica water theme park and resort',
#  'OWNER Name': '',
#  'RESORT NUMBER': '09331555220 ; 08961618395',
#  'Whatsapp': '',
#  'YES / NO': 'No',
#  '_id': ObjectId('5f01eee936ce0711bce7e6f9'),
#  'call status': '',
#  'caller': '',
#  'no': '3',
#  'pax': '120'}
# {'ADDRESS': '206, 206B, Banku Bihari Chatterjee Rd, Bosepukur, Kasba, Kolkata, '
#             'West Bengal 700042\n'
#             '\n',
# ...

# %%
db.addresses.insert_one({'ADDRESS': 'varanasi',
 'Action -2': '',
 'CATEGORY': 'RESORT',
 'Email address': 'jaba.licu@gmail.com',
 'NAME OF RESORT': 'Aquafina resort',
 'OWNER Name': 'JABA',
 'RESORT NUMBER': '9331555220 ; 08240522866 ; 08961618395',
 'Whatsapp': '',
 'YES / NO': 'Yes',
  'call status': '',
 'caller': 'Suprava',
 'no': '1',
 'pax': '111'
    
})

# %%
db.addresses.insert_many({'ADDRESS': 'varanasi',
 'Action -2': '',
 'CATEGORY': 'RESORT',
 'Email address': 'jaba.licu@gmail.com',
 'NAME OF RESORT': 'Aquafina resort',
 'OWNER Name': 'JABA',
 'RESORT NUMBER': '9331555220 ; 08240522866 ; 08961618395',
 'Whatsapp': '',
 'YES / NO': 'Yes',
  'call status': '',
 'caller': 'Suprava',
 'no': '1',
 'pax': '111'
},
{'ADDRESS': 'varanasi',
 'Action -2': '',
 'CATEGORY': 'RESORT',
 'Email address': 'jaba.licu@gmail.com',
 'NAME OF RESORT': 'Aquafina resort',
 'OWNER Name': 'JABA',
 'RESORT NUMBER': '9331555220 ; 08240522866 ; 08961618395',
 'Whatsapp': '',
 'YES / NO': 'Yes',
  'call status': '',
 'caller': 'Suprava',
 'no': '1',
 'pax': '111'
})

# %%
# query to find all No
cursor = db.addresses.find({"YES / NO":"NO"})

# %%
list(cursor)

# %%
for address in cursor:
    pprint(len(address))

# %%
http://localhost:8888/notebooks/Documents/MongoDB_tutorial%20with%20cloud.ipynb
